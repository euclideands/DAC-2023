# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from ydata_profiling import ProfileReport

# %% [markdown]
# # Import Dataset

# %%
# Path to training and prediction dataset
train_PATH = 'D:\DAC-2023\Dataset\DataTrain_Preliminary.csv'
pred_PATH = 'D:\DAC-2023\Dataset\Data_Prediction.csv'

# %%
# Load training data 
df = pd.read_csv(train_PATH, delimiter=';')
df
# Out:
#        duration protocol_type  service  flag src_bytes dst_bytes land  \
# 0             0           tcp  private    SH         0         0    0
# 1             0           tcp  private    S0         0         0    0
# 2             0           tcp     http    SF       285      3623    0
# 3             0           tcp     http    SF       232       584    0
# 4             1           tcp     smtp    SF      1080       327    0
# ...         ...           ...      ...   ...       ...       ...  ...
# 112441        0           tcp     http   REJ         0         0    0
# 112442        0           tcp     http    SF       309       758    0
# 112443        0           tcp     http    SF       363       721    0
# 112444        0           tcp  discard  RSTO         0         0    0
# 112445        0           tcp     http    SF       233      2538    0
#
#        wrong_fragment urgent hot  ... dst_host_srv_count  \
# 0                   0      0   0  ...                  1
# ...

# %% [markdown]
# # Duplicate Data Investigation

# %%
ProfileReport(df).get_duplicates()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#        duration protocol_type  service  flag src_bytes dst_bytes land  \
# 0             0           tcp  private    SH         0         0    0
# 1             0           tcp  private    S0         0         0    0
# 2             0           tcp     http    SF       285      3623    0
# 3             0           tcp     http    SF       232       584    0
# 4             1           tcp     smtp    SF      1080       327    0
# ...         ...           ...      ...   ...       ...       ...  ...
# 112440        5           tcp     smtp    SF      1377       328    0
# 112442        0           tcp     http    SF       309       758    0
# 112443        0           tcp     http    SF       363       721    0
# 112444        0           tcp  discard  RSTO         0         0    0
# 112445        0           tcp     http    SF       233      2538    0
#
#        wrong_fragment urgent hot  ... dst_host_srv_count  \
# 0                   0      0   0  ...                  1
# ...

# %% [markdown]
# # Unique Value Investigation

# %%
# Initialize a dictionary to store missing value representations
missing_value_representations = ['', ' ', '-', 'NA', 'N/A', '999', '-999', None, np.nan, '*', '9999', '-9999', '99999', '-99999']

# Initialize a set to store unique types of missing values
unique_missing_value_types = set()

# Iterate through columns and check for missing value representations
for column in df.columns:
    for value in df[column]:
        if value in missing_value_representations:
            unique_missing_value_types.add(value)

# Boolean indexing to filter rows with unique missing value types
filtered_df = df[df.apply(lambda row: any(val in unique_missing_value_types for val in row), axis=1)]

# Display the filtered DataFrame
print("Unique types of missing values found in the DataFrame:")
print(unique_missing_value_types)
print("Rows containing unique missing value types:")
filtered_df
# Out:
# Unique types of missing values found in the DataFrame:
# {nan, '99999', '*', '999'}
# Rows containing unique missing value types:
#        duration protocol_type  service  flag src_bytes dst_bytes land  \
# 1             0           tcp  private    S0         0         0    0
# 2             0           tcp     http    SF       285      3623    0
# 3             0           tcp     http    SF       232       584    0
# 4             1           tcp     smtp    SF      1080       327    0
# 5             0           tcp  discard    S0         0         0    0
# ...         ...           ...      ...   ...       ...       ...  ...
# 112441        0           tcp     http   REJ         0         0    0
# 112442        0           tcp     http    SF       309       758    0
# 112443        0           tcp     http    SF       363       721    0
# 112444        0           tcp  discard  RSTO         0         0    0
# 112445        0           tcp     http    SF       233      2538    0
# ...

# %% [markdown]
# # Investigate Unique Value Based on Type of Attack

# %%
# Identifying and listing the unique attack types present in the column
attack_type = df['type_of_attack'].unique()
print(f"Value contain in type_of_attack column:\n{attack_type}")
# Out:
# Value contain in type_of_attack column:
# ['nmap' 'neptune' 'normal' 'Denial of Service Attack' 'portsweep' 'satan'
#  'ipsweep' 'smurf']

# %%
# Exploring the distribution of these attack types to understand their prevalence in the dataset.
attack_type_counts = df['type_of_attack'].value_counts()
attack_type_counts
# Out:
# type_of_attack
# normal                      60169
# neptune                     36832
# ipsweep                      3036
# satan                        2905
# portsweep                    2651
# smurf                        2378
# Denial of Service Attack     1746
# nmap                         1322
# Name: count, dtype: int64

# %%
# Exploring the distribution of these attack types to understand their prevalence in the dataset.
attack_type_counts = df['type_of_attack'].value_counts()
total_samples = len(df)
attack_type_percentages = (attack_type_counts / total_samples) * 100

# Round the percentages to two decimal places
attack_type_percentages = attack_type_percentages.round(2)

# Print the percentages 
print(attack_type_percentages.astype(str) + '%')
# Out:
# type_of_attack
# normal                      54.19%
# neptune                     33.17%
# ipsweep                      2.73%
# satan                        2.62%
# portsweep                    2.39%
# smurf                        2.14%
# Denial of Service Attack     1.57%
# nmap                         1.19%
# Name: count, dtype: object

# %%
# Function to filter df based on type of attack
def filtered_by_type_of_attack(df, values):
    filtered = df[df['type_of_attack'] == values]
    return filtered

# %% [markdown]
# ## Normal

# %%
normal = filtered_by_type_of_attack(df, 'normal')
normal.head()
# Out:
#   duration protocol_type   service flag src_bytes dst_bytes land  \
# 2        0           tcp      http   SF       285      3623    0
# 3        0           tcp      http   SF       232       584    0
# 4        1           tcp      smtp   SF      1080       327    0
# 6        0           udp  domain_u   SF        43        43    0
# 8        0           tcp      http   SF       284       614    0
#
#   wrong_fragment urgent hot  ... dst_host_srv_count dst_host_same_srv_rate  \
# 2              0      0   0  ...                228                   1.00
# 3              0      0   0  ...                255                   1.00
# 4              0      0   0  ...                154                   0.58
# 6              0      0   0  ...                254                   1.00
# 8              0      0   0  ...                255                   1.00
#
#   dst_host_diff_srv_rate dst_host_same_src_port_rate  \
# 2                   0.00                        0.01
# ...

# %% [markdown]
# ### Bool Data Type

# %%
value_counts = normal['land'].value_counts()
print(value_counts)
# Out:
# land
# 0        59937
# 99999      144
# *           81
# 1            7
# Name: count, dtype: int64

# %%
# Determine a probability threshold based on the existing distribution
# In this example, we'll use the probability of 0 as the threshold
probability_of_0 = value_counts.get(0, 0) / len(normal)

# Convert '*' and '99999' values based on the threshold
def convert_value(value):
    if value == '*':
        return 0 if np.random.rand() <= probability_of_0 else 1
    elif value == '99999':
        return 0 if np.random.rand() <= probability_of_0 else 1
    else:
        return int(value)

# Apply the conversion function to the 'land' column
normal['land'] = normal['land'].apply(convert_value)

# %%
value_counts = normal['land'].value_counts()
print(value_counts)
# Out:
# land
# 0        59937
# 99999      144
# *           81
# 1            7
# Name: count, dtype: int64
